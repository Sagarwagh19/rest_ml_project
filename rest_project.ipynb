# %%
print('Hii')
# Out:
# Hii

# %%
import pandas as pd
import numpy as np
import flask
import pymysql
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
#Restaurant review prediction systems
#Sentiments analysis of restaurant reviews

# %%
#owner>>cust>>text>>model>>good or bad>>Analysis
#food>>quality increase
#kaggle

# %%
#Define problem statement

#Normally, a lot of businesses are remained as failures due to lack of profit, lack of proper improvement 
# measures. Mostly, restaurant owners face a lot of difficulties to improve their productivity.
# This project really helps those who want to increase their productivity,
# which in turn increases their business profits. This is the main objective of this project.
#What the project does is that the restaurant owner gets to know about drawbacks of his restaurant 
# such as most disliked food items of his restaurant by customer’s text review which is processed 
# with ML classification algorithm(Naive Bayes)
#The purpose of this analysis is to build a prediction model to predict whether a review on the 
# restaurant is positive or negative. To do so, we will work on Restaurant Review dataset, 
# we will load it into predicitve algorithms Multinomial Naive Bayes, Bernoulli Naive Bayes 
# and Logistic Regression. In the end, we hope to find a "best" model for predicting 
# the review's sentiment.

# %%
#Step-1 data collection

#Dataset: Restaurant_Reviews.tsv is a dataset from Kaggle datasets which consists of 1000 reviews on a restaurant.

#To build a model to predict if review is positive or negative, following steps are performed.

#Importing Dataset
#Preprocessing Dataset
#Vectorization
#Training and Classification
#Analysis Conclusion

# %%
# Tools & Technologies Used:
# NLTK
# Machine Learning
# Python
# Tkinter
# Mysql
# Pandas
# flask
# git and github

# %%
#Step 1 Data collection

# %%
import pandas as pd
import numpy as np
import flask
import pymysql
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
df=pd.read_csv('r_data.tsv',delimiter='\t')

# %%
df
# Out:
#                                                  Review  Liked
# 0                              Wow... Loved this place.      1
# 1                                    Crust is not good.      0
# 2             Not tasty and the texture was just nasty.      0
# 3     Stopped by during the late May bank holiday of...      1
# 4     The selection on the menu was great and so wer...      1
# ...                                                 ...    ...
# 1381                                              clean      1
# 1382                                               less      0
# 1383                                              clean      1
# 1384                                               less      0
# 1385                                              clean      1
#
# [1386 rows x 2 columns]

# %%
df.shape
# Out:
# (1386, 2)

# %%
#Data Cleaning

# %%
df.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
df.dtypes
# Out:
# Review      str
# Liked     int64
# dtype: object

# %%
#1>>Positive/Good
#0>>Negative/Bad

# %%
#Step3 EDA/Text Preprocessing
#Remove Stop Words  
# steaming
# lowercase

# %%
X=df['Review']
y=df['Liked']

# %%
y.value_counts()
# Out:
# Liked
# 1    792
# 0    594
# Name: count, dtype: int64

# %%
#Dataset i balanced

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
import re

# %%
#Lowercase
text='Hi how are you'
newtext=text.lower()
print(newtext)
# Out:
# hi how are you

# %%
#Remove digit or digital chars
text='Hi ^&# how are you?'
newresult=re.sub(r'[^a-zA-Z\s]','',text)
print(newresult)
# Out:
# Hi  how are you

# %%
#Tokenization>>Break down sentence into words
text='Hi how are you'
list1=word_tokenize(text)
print(list1)
# Out:
# ['Hi', 'how', 'are', 'you']

# %%
#Remove stop words
#Stopwords>> most common words
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Sagar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\Sagar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Sagar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Sagar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
s_list=stopwords.words('english')

# %%
len(s_list)
# Out:
# 198

# %%
text='cat sat on mat and this is real problem'
list1=word_tokenize(text)
print(list1)
# Out:
# ['cat', 'sat', 'on', 'mat', 'and', 'this', 'is', 'real', 'problem']

# %%
list2=[i for i in list1 if i not in s_list]

# %%
list2
# Out:
# ['cat', 'sat', 'mat', 'real', 'problem']

# %%
#Stemming/lemmatization
#to get root word
#to cut off siffixes
#affect affecting affected>>affect

# %%
ps=PorterStemmer()
ps.stem('affected')
# Out:
# 'affect'
